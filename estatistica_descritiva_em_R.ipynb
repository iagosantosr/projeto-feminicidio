# %%
import pandas as pd 
import io
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/iagosantosr/projeto-feminicidio/master/Feminicidio_2015_2022.xlsx%20-%20feminicidio_2015_2022.csv'
df = pd.read_csv(url)

# %%
df.head()

# %%
print(df['ANO ESTATISTICA'].mean())
# Out:
# 2019.1253761283851

# %%
print(df['ANO ESTATISTICA'].median())
# Out:
# 2019.0

# %%
print(df['ANO ESTATISTICA'].quantile())
# Out:
# 2019.0

# %%
print(df['ANO ESTATISTICA'].quantile(q=0.25))
# Out:
# 2018.0

# %%
print(df['ANO ESTATISTICA'].mode())
# Out:
# 0    2019
# dtype: int64

# %%
print(df['ANO ESTATISTICA'].max() - df['ANO ESTATISTICA'].min())
# Out:
# 7

# %%
print(df['ANO ESTATISTICA'].var())
# Out:
# 3.770409622441621

# %%
print(df['ANO ESTATISTICA'].std())
# Out:
# 1.941754264174955

# %%
print(df['ANO ESTATISTICA'].mad())
# Out:
# 1.6034703911131576

# %%
print(df.cov())
# Out:
#                    Nº DE VÍT HD  ID_DELEGACIA  MÊS ESTATISTICA  \
# Nº DE VÍT HD                0.0  0.000000e+00         0.000000
# ID_DELEGACIA                0.0  4.316153e+09     -3407.124595
# MÊS ESTATISTICA             0.0 -3.407125e+03        12.250140
# ANO ESTATISTICA             0.0  1.284891e+02        -1.165478
# ANO_BO                      0.0  1.128181e+02        -1.159967
# NUMERO_LOGRADOURO           0.0  5.600997e+06       -12.862354
# IDADE_PESSOA                0.0  2.290937e+04        -0.622763
#
#                    ANO ESTATISTICA      ANO_BO  NUMERO_LOGRADOURO  \
# Nº DE VÍT HD              0.000000    0.000000       0.000000e+00
# ID_DELEGACIA            128.489096  112.818117       5.600997e+06
# MÊS ESTATISTICA          -1.165478   -1.159967      -1.286235e+01
# ANO ESTATISTICA           3.770410    3.772292       6.596962e+02
# ANO_BO                    3.772292    3.775177       6.596962e+02
# ...

# %%
print(df.corr())
# Out:
#                    Nº DE VÍT HD  ID_DELEGACIA  MÊS ESTATISTICA  \
# Nº DE VÍT HD                NaN           NaN              NaN
# ID_DELEGACIA                NaN      1.000000        -0.014817
# MÊS ESTATISTICA             NaN     -0.014817         1.000000
# ANO ESTATISTICA             NaN      0.001007        -0.171490
# ANO_BO                      NaN      0.000884        -0.170571
# NUMERO_LOGRADOURO           NaN      0.010554        -0.000466
# IDADE_PESSOA                NaN      0.025402        -0.012991
#
#                    ANO ESTATISTICA    ANO_BO  NUMERO_LOGRADOURO  IDADE_PESSOA
# Nº DE VÍT HD                   NaN       NaN                NaN           NaN
# ID_DELEGACIA              0.001007  0.000884           0.010554      0.025402
# MÊS ESTATISTICA          -0.171490 -0.170571          -0.000466     -0.012991
# ANO ESTATISTICA           1.000000  0.999867           0.042547      0.009463
# ...

# %%
print(df.describe())
# Out:
#        Nº DE VÍT HD   ID_DELEGACIA  MÊS ESTATISTICA  ANO ESTATISTICA  \
# count         997.0     997.000000       997.000000       997.000000
# mean            1.0   65917.294885         6.510532      2019.125376
# std             0.0   65697.437494         3.500020         1.941754
# min             1.0   10101.000000         1.000000      2015.000000
# 25%             1.0   30127.000000         3.000000      2018.000000
# 50%             1.0   60405.000000         6.000000      2019.000000
# 75%             1.0  100402.000000        10.000000      2021.000000
# max             1.0  900556.000000        12.000000      2022.000000
#
#             ANO_BO  NUMERO_LOGRADOURO  IDADE_PESSOA
# count   997.000000         323.000000    989.000000
# mean   2019.126379        1218.820433     35.947422
# std       1.942981        7955.772864     13.700279
# min    2015.000000           0.000000      1.000000
# 25%    2018.000000          14.500000     27.000000
# ...
